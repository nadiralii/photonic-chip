# %%
import gdsfactory as gf
import matplotlib.pyplot as plt
import numpy as np
import tidy3d as td
from gdsfactory.components.taper import taper_sc_nc

import gplugins.tidy3d as gt
from gplugins import utils
from gplugins.config import PATH

gf.config.rich_output()
PDK = gf.generic_tech.get_generic_pdk()
PDK.activate()
# Out:
# 2023-08-30 10:59:41.443 | INFO     | gdsfactory.technology.layer_views:__init__:810 - Importing LayerViews from YAML file: '/home/nadir/anaconda3/lib/python3.11/site-packages/gdsfactory/generic_tech/layer_views.yaml'.
# 2023-08-30 10:59:41.460 | INFO     | gdsfactory.pdk:activate:341 - 'generic' PDK is now active

# %%
c = gf.components.mzi()
s = gt.get_simulation(c)
fig = gt.plot_simulation(s)
# Out:
# 2023-08-30 10:59:41.657 | WARNING  | gdsfactory.klive:show:48 - Could not connect to klive server. Is klayout open and klive plugin installed?
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1100x400 with 4 Axes>

# %%
c.plot()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.lib.display.IFrame object at 0x7f3727f9e8d0>
