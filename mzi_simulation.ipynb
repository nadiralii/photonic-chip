# %%
import gdsfactory as gf
import matplotlib.pyplot as plt
import numpy as np
import tidy3d as td
from gdsfactory.components.taper import taper_sc_nc

import gplugins.tidy3d as gt
from gplugins import utils
from gplugins.config import PATH

gf.config.rich_output()
PDK = gf.generic_tech.get_generic_pdk()
PDK.activate()
# Out:
# 2023-08-24 22:53:06.116 | INFO     | gdsfactory.technology.layer_views:__init__:782 - Importing LayerViews from YAML file: '/home/nadir/anaconda3/lib/python3.11/site-packages/gdsfactory/generic_tech/layer_views.yaml'.
# 2023-08-24 22:53:06.142 | INFO     | gdsfactory.pdk:activate:316 - 'generic' PDK is now active

# %%
c = gf.components.mzi()
s = gt.get_simulation(c)
fig = gt.plot_simulation(s)
# Out:
# 2023-08-24 22:53:07.121 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.2.2", "type": "open", "file": "/tmp/gdsfactory/mzi.gds"}

# %%
c.plot()
# Out:
#         <iframe
#             width="1400"
#             height="600"
#             src="http://127.0.0.1:8000/gds?gds_file=/home/nadir/.gdsfactory/extra/mzi.gds&layer_props=/tmp/gdsfactory/layers.lyp"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
s = gt.get_simulation(c, plot_modes=True)
fig = gt.plot_simulation(s)
# Out:
# 2023-08-24 22:54:15.438 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.2.2", "type": "reload", "file": "/tmp/gdsfactory/mzi.gds"}
# Effective index of computed modes:  [[2.4556725 1.8037537]]
